# %% [markdown]
# ### Create unique company list
#
# This is used as disconnected table in my semantic model to be able to highlight individual companies.

# %%
# %%sql
# CREATE OR REPLACE TABLE dim_company_highlight AS
# SELECT DISTINCT
#     Company_Name
# FROM gold_company_profile;
# Out:
# StatementMeta(, 47dc8a56-d268-4c7f-a3d2-b2e2908046d7, 2, Finished, Available, Finished, False)
# <Spark SQL result set with 0 rows and 0 fields>
