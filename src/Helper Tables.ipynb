# %%
# %%sql
# CREATE TABLE dim_boxplot_rows (
#     label_id INT,
#     label STRING
# );
#
# INSERT INTO dim_boxplot_rows VALUES
# (1, 'n'),
# (2, 'P10'),
# (3, 'P25'),
# (4, 'Median'),
# (5, 'P75'),
# (6, 'P90'),
# (7, 'Selected Company');
# Out:
# StatementMeta(, 86417303-4492-4034-a1bb-69ba7a01b2fb, 6, Finished, Available, Finished, True)
# <Spark SQL result set with 0 rows and 0 fields>
# <Spark SQL result set with 0 rows and 0 fields>

# %%
# %%sql
# CREATE TABLE role_dim (
#     role_id INT,
#     role_name STRING
# )
# USING DELTA;
#
# INSERT INTO role_dim (role_id, role_name) VALUES
#     (1, 'CEO'),
#     (2, 'OBM');
# Out:
# StatementMeta(, a98d8a5d-da65-401b-8fab-c92e3c1ee340, 4, Finished, Available, Finished, True)
# <Spark SQL result set with 0 rows and 0 fields>
# <Spark SQL result set with 0 rows and 0 fields>
