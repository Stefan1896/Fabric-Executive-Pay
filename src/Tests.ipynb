# %%
import edgar
from edgar import Company, set_identity
set_identity("dein.name@domain.com")

c = Company("DIS")
filings = c.get_filings()          # keine Argumente erlaubt
def14a_filings = filings.filter(form="DEF 14A")
latest = def14a_filings.latest()

proxy = latest.obj()

#proxy.executive_compensation
proxy.pay_vs_performance
# Out:
# StatementMeta(, 092b4eaf-4d55-4223-a479-ec4e328df055, 10, Finished, Available, Finished, True)
#   fiscal_year_end  peo_actually_paid_comp  neo_avg_actually_paid_comp  \
# 0      2021-10-02                     0.0                  44993365.0
# 1      2022-10-01                     0.0                 -10064462.0
# 2      2023-09-30              21754776.0                   6086670.0
# 3      2024-09-28              40704301.0                  11779931.0
# 4      2025-09-27                     0.0                  16531677.0
#
#    total_shareholder_return  peer_group_tsr  net_income  \
# 0                    143.62          130.93      2507.0
# 1                     76.97           96.57      3505.0
# 2                     66.14          128.38      3390.0
# 3                     78.96          180.06      5773.0
# 4                     94.13          224.99     13431.0
#
#    company_selected_measure_value
# 0                          4055.0
# 1                         12121.0
# ...
